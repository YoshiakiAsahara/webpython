# %% [markdown]
# <a href="https://colab.research.google.com/github/YoshiakiAsahara/webpython/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.style
#ggplotstyleを指定
matplotlib.style.use('ggplot')

# %%
x = [1, 2, 3]
y = [2, 4, 9]

plt.plot(x, y)
plt.title('pyplot interface')

plt.show()

# %% [markdown]
# 描画オブジェクト（fig）を生成し、一つ以上のサブプロット（ax）を生成

# %%
x = [1, 2, 3]
y = [2, 4, 9]
fig, ax =plt.subplots()

ax.plot(x, y)
ax.set_title('object_oriented_interfase')
# Out:
# Text(0.5, 1.0, 'object_oriented_interfase')

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2)#二つのサブプロットを配置
plt.show()

# %%
fig, axes= plt.subplots(2,2)
plt.show()

# %%
fig, axes = plt.subplots(ncols=2, nrows=2)
plt.show()

# %%
fig, ax =plt.subplots()

ax.set_xlabel('x label')
ax.set_ylabel('y_label')

plt.show()

# %%
plt, ax =plt.subplots()

#凡庸例のラベルを設定
ax.plot([1, 2, 3], [2, 4, 9], label='legend_label')
ax.legend(loc='best')

# %%
import matplotlib.pyplot as plt

# %%
fig, ax =plt.subplots()
ax.plot([1, 2, 3], [2, 4, 9], label='legend label')
ax.legend(loc='lower right')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax =plt.subplots()
ax.set_title('subplot title')
fig.savefig('sample-figure.png')
fig.savefig('sample-figure.png')

# %%
fig, ax = plt.subplots()

x = [1, 2, 3]
y1 = [1, 2, 3]
y2 = [3, 1, 2]
ax.plot(x, y1)
ax.plot(x,y2)

# %%
import numpy as np
x = np.arange(0.0, 15.0, 0.1)
y1 =np.sin(x)
y2 = np.cos(x)
fig, ax =plt.subplots()
ax.plot(x, y1, label='sin')
ax.plot(x, y2, label='cos')
ax.legend()

plt.show()

# %% [markdown]
# 棒グラフ

# %%
fig, ax =plt.subplots()

x=[1, 2, 3]
y = [10, 2, 3]
ax.bar(x, y)#棒グラフを描画

plt.show()

# %%
fig, ax =plt.subplots()

x = [1, 2, 3]
y = [10, 2, 3]
labels = ['spam', 'ham', 'egg']
ax.bar(x, y, tick_label=labels)
plt.show()

# %% [markdown]
# barhメソッドを用いたら横向きになる。

# %%
fig, ax =plt.subplots()

x = [1, 2, 3]
y = [10, 2, 3]
labels = ['spam', 'ham', 'egg']
ax.barh(x, y, tick_label=labels)
plt.show()

# %%
fig, ax = plt.subplots()

x = [1, 2, 3]
y1 = [10, 2, 3]
y2 =[5, 3, 6]
labels = ['spam', 'ham', 'egg']

width = 0.4 #棒グラフの幅を0.4
ax.bar(x, y1, width=width, tick_label=labels,
       label='y1')
#幅分ずらして棒グラフを描画
x2 = [num + width for num in x]
ax.bar(x2, y2, width, label='y2')

ax.legend()
plt.show()

# %%
fig, ax =plt.subplots()

x = [1, 2, 3]
y1 = [10, 2, 3]
y2 = [5, 3, 6]
y3 = [3, 2, 8]
labels = ['spam', 'ham', 'egg']

#y1とy2を足した値を格納
y1_y2 = [num1 + num2 for num1, num2 in zip(y1, y2)]
ax.bar(x, y1, tick_label=labels, label='y1')
#y2の棒グラフのベースの座標にy1を指定
ax.bar(x, y2, bottom=y1, label='y2')
#y3の棒グラフのベースのy座標にy1+y2を指定
ax.bar(x, y3, bottom=y1_y2, label='y3')
ax.legend()

plt.show()

# %% [markdown]
# 散布図

# %%
fig, ax =plt.subplots()

#ランダムに50個の要素を指定
rng = np.random.default_rng(123)
x = rng.random(50)
y = rng.random(50)

ax.scatter(x, y) #散布図を描画

plt.show()

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

#ランダムに50個の要素を生成
rng = np.random.default_rng(123)
x = rng.random(50)
y = rng.random(50)

ax.scatter(x[0:10], y[0:10], marker='v',
           label='triangle_down')
ax.scatter(x[10:20], y[10:20], marker='^',
           label='triangle_up')
ax.scatter(x[20:30], y[20:30], marker='s',
           label='squre')
ax.scatter(x[30:40], y[30:40], marker='*',
           label='star')
ax.scatter(x[40:50], y[40:50], marker='x',
           label='x')
ax.legend()

plt.show()

# %% [markdown]
# ヒストグラム

# %%
#データ生成
rng = np.random.default_rng(123)
mu = 100
sigma = 15
x = rng.normal(mu, sigma, 1000)
fig, ax = plt.subplots()

n, bins, pathes =ax.hist(x)

plt.show()

# %%
for i, num in enumerate(n):
  print(f"{bins[i]:.2f} - {bins[i+1]:.2f}: {num}")
# Out:
# 50.53 - 60.06: 8.0
# 60.06 - 69.60: 22.0
# 69.60 - 79.13: 50.0
# 79.13 - 88.66: 123.0
# 88.66 - 98.20: 236.0
# 98.20 - 107.73: 250.0
# 107.73 - 117.27: 172.0
# 117.27 - 126.80: 111.0
# 126.80 - 136.34: 22.0
# 136.34 - 145.87: 6.0

# %%
fig, ax = plt.subplots()
ax.hist(x, bins=25)
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist(x, orientation='horizontal')

plt.show()

# %%
rng = np.random.default_rng(123)
mu = 100
x0 = rng.normal(mu, 20, 1000)

#異なる標準偏差でデータを生成
x1 = rng.normal(mu, 15, 1000)
x2 = rng.normal(mu, 10, 1000)

fig, ax = plt.subplots()

labels = ['x0', 'x1', 'x2']
#3つのデータのヒストグラムを描画
ax.hist((x0, x1, x2), label='labels')
ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()

labels = ['x0', 'x1', 'x2']
#積み上げたヒストグラムを描画
ax.hist((x0, x1, x2), label=labels, stacked=True)
ax.legend()

plt.show()

# %%
rng = np.random.default_rng(123)
x0 = rng.normal(0, 10, 500)
x1 = rng.normal(0, 15, 500)
x2 = rng.normal(0, 20, 500)

fig, ax = plt.subplots()
labels=['xp', 'x1', 'x2']
ax.boxplot((x0, x1, x2), labels=labels)
plt.show()

# %%
fig, ax = plt.subplots()
labels=['xp', 'x1', 'x2']
ax.boxplot((x0, x1, x2), labels=labels, vert=False)
plt.show()

# %%
labels=['spam', 'ham', 'egg']
x = [10, 3,1]

fig, ax =plt.subplots()

ax.pie(x, labels=labels)
plt.show()

# %%
fig, ax =plt.subplots()

ax.pie(x, labels=labels, startangle=90,
       counterclock=False)
plt.show()

# %%
fig, ax = plt.subplots()
ax.pie(x, labels=labels, startangle=90,
       counterclock=False,
       shadow=True, autopct='%1.2f%%')#影と%表記を追加
plt.show()

# %%
explode = [0, 0.2, 0]
fig, ax =plt.subplots()

ax.pie(x, labels=labels, startangle=90, counterclock=False,
       shadow=True, autopct='%1.2f%%',
       explode=explode)
plt.show()

# %%
fig, ax =plt.subplots()

x1 = [1, 2, 3]
y1 = [5, 2, 3]
x2 = [1, 2, 3, 4]
y2 = [8, 5, 4, 6]
ax.bar(x1, y1, label='y1')
ax.plot(x2, y2, label='y2')
ax.legend()

plt.show()

# %%
rng = np.random.default_rng(123)
x = rng.normal(size=1000)

fig, ax = plt.subplots()

counts, edges, patches = ax.hist(x, bins=25)
#近似曲線に用いる点を求める
x_fit = (edges[:-1] + edges[1:]) / 2
#近似曲線をプロット
y = 1000 * np.diff(edges)* np.exp(-x_fit**2 / 2) /np.sqrt(2*np.pi)
ax.plot(x_fit, y)

# %%
fig, ax = plt.subplots()
#線の色を名前で指定
ax.plot([1, 3], [3, 1], label='aqua', color='aqua')
#16進数のRBGで指定
ax.plot([1,3], [1, 3], label='#0000FF', color='#0000FF')
#RGBAをfloatで指定
ax.plot([1, 3], [2, 2], label='(0.1, 0.2, 0.5, 0.3)', color=(0.1, 0.2, 0.5, 0.3))

ax.legend()
plt.show()

# %%
fig, ax =plt.subplots()

ax.bar([1], [3], color='aqua')#塗りつぶしの色を指定
#塗りつぶしの色と枠千の色を指定

ax.bar([2], [4], color='aqua', edgecolor='black')

plt.show()

# %%
fig, ax = plt.subplots()
#5.5ポイントの幅の線で描画
ax.plot([1, 3], [3, 1], linewidth=5.5, label='5.5')
#10ポイントの線で描画
ax.plot([1,3], [1, 3], linewidth=10, label='10')
ax.legend()

plt.show()

# %%
fig, ax = plt.subplots()
#破線
ax.plot([1,3], [3, 1], linestyle='--', label='dashed')
#一点鎖線
ax.plot([1,3], [1, 3], linestyle='-.', label='dashdot')
#点線
ax.plot([1,3], [2,2], linestyle=':', label='dotted')

# %%
fig, ax =plt.subplots()

ax.set_xlabel('xlabel', family='fantasy', size=20,
              weight='bold')
ax.set_ylabel('ylabel', family='serif', size=40,
              weight='light')
ax.set_title('graph title', family='monospace',
             size=25, weight='heavy')
# Out:
# Text(0.5, 1.0, 'graph title')

# %%
fig, ax = plt.subplots()

ax.text(0.2, 0.4, 'Text', size=20)#Textを描画
plt.show()

# %%
import matplotlib.style

#スタイル一覧の表示
print(matplotlib.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
#グラフのスタイルをクラシックに設定
matplotlib.style.use('classic')

fig, ax = plt.subplots()
ax.plot([1,2])

plt.show()

# %%
import pandas as pd
import matplotlib.style
import matplotlib.pyplot as plt

# %%
matplotlib.style.use('ggplot')#スタイルを指定
#DataFrameを作成
df = pd.DataFrame({'A': [1, 2, 3], 'B': [3, 1, 2]})
df.plot()
plt.show()

# %%
import numpy as np
#ランダムに3行二列のデータを生成
rng = np.random.default_rng(123)
df2 = pd.DataFrame(rng.random((3, 2)), columns=['y1', 'y2'])

df2.plot.bar()
plt.show()

# %%
df2.plot.bar(stacked=True)
plt.show()
